# %%
# importing the libraries
import numpy as np
import pandas as pd

# %%
# 1. Clevland database:

df_clevland = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data', header=None)
df_clevland.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df_clevland.head()
# Out:
#     age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  target
# 0    3.0  0.0  6.0       0
# 1    2.0  3.0  3.0       2
# 2    2.0  2.0  7.0       1
# 3    3.0  0.0  3.0       0
# 4    1.0  0.0  3.0       0

# %%
# 2. Hungary database:

df_hungary = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data', header=None)
df_hungary.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df_hungary.head()
# Out:
#    age  sex  cp trestbps chol fbs restecg thalach exang  oldpeak slope ca  \
# 0   28    1   2      130  132   0       2     185     0      0.0     ?  ?
# 1   29    1   2      120  243   0       0     160     0      0.0     ?  ?
# 2   29    1   2      140    ?   0       0     170     0      0.0     ?  ?
# 3   30    0   1      170  237   0       1     170     0      0.0     ?  ?
# 4   31    0   2      100  219   0       1     150     0      0.0     ?  ?
#
#   thal  target
# 0    ?       0
# 1    ?       0
# 2    ?       0
# 3    6       0
# 4    ?       0

# %%
# 3. Switzerland database:

df_switzerland = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.switzerland.data', header=None)
df_switzerland.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df_switzerland.head()
# Out:
#    age  sex  cp trestbps  chol fbs restecg thalach exang oldpeak slope ca  \
# 0   32    1   1       95     0   ?       0     127     0      .7     1  ?
# 1   34    1   4      115     0   ?       ?     154     0      .2     1  ?
# 2   35    1   4        ?     0   ?       0     130     1       ?     ?  ?
# 3   36    1   4      110     0   ?       0     125     1       1     2  ?
# 4   38    0   4      105     0   ?       0     166     0     2.8     1  ?
#
#   thal  target
# 0    ?       1
# 1    ?       1
# 2    7       3
# 3    6       1
# 4    ?       2

# %%
# 4. VA database:

df_va = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.va.data', header=None)
df_va.columns = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df_va.head()
# Out:
#    age  sex  cp trestbps chol fbs  restecg thalach exang oldpeak slope ca  \
# 0   63    1   4      140  260   0        1     112     1       3     2  ?
# 1   44    1   4      130  209   0        1     127     0       0     ?  ?
# 2   60    1   4      132  218   0        1     140     1     1.5     3  ?
# 3   55    1   4      142  228   0        1     149     1     2.5     1  ?
# 4   66    1   3      110  213   1        2      99     1     1.3     2  ?
#
#   thal  target
# 0    ?       2
# 1    ?       0
# 2    ?       2
# 3    ?       1
# 4    ?       0

# %%
print('Number of rows in clevland dataset:', df_clevland.shape[0])
print('Number of rows in hungary dataset:', df_hungary.shape[0])
print('Number of rows in switzerland dataset:', df_switzerland.shape[0])
print('Number of rows in va dataset:', df_va.shape[0])
# Out:
# Number of rows in clevland dataset: 303
# Number of rows in hungary dataset: 294
# Number of rows in switzerland dataset: 123
# Number of rows in va dataset: 200

# %%
# Combining the dataframes:

df = pd.concat([df_clevland, df_hungary, df_switzerland, df_va])

# %%
# Number of rows and columns in the dataframe:
df.shape
# Out:
# (920, 14)

# %%
df.head()
# Out:
#     age  sex   cp trestbps chol fbs restecg thalach exang oldpeak slope   ca  \
# 0  63.0  1.0  1.0      145  233   1       2     150     0     2.3     3  0.0
# 1  67.0  1.0  4.0      160  286   0       2     108     1     1.5     2  3.0
# 2  67.0  1.0  4.0      120  229   0       2     129     1     2.6     2  2.0
# 3  37.0  1.0  3.0      130  250   0       0     187     0     3.5     3  0.0
# 4  41.0  0.0  2.0      130  204   0       2     172     0     1.4     1  0.0
#
#   thal  target
# 0  6.0       0
# 1  3.0       2
# 2  7.0       1
# 3  3.0       0
# 4  3.0       0

# %%
# feature data types:
df.dtypes
# Out:
# age         float64
# sex         float64
# cp          float64
# trestbps     object
# chol         object
# fbs          object
# restecg      object
# thalach      object
# exang        object
# oldpeak      object
# slope        object
# ca           object
# thal         object
# target        int64
# dtype: object

# %%
# checking null values:
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['thal'].value_counts()
# Out:
# ?      486
# 3.0    166
# 7.0    117
# 7       75
# 3       30
# 6       28
# 6.0     18
# Name: thal, dtype: int64

# %%
print('Number of ? in age', df[df['age']=='?'].shape[0])
print('Number of ? in sex', df[df['sex']=='?'].shape[0])
print('Number of ? in cp', df[df['cp']=='?'].shape[0])
print('Number of ? in trestbps', df[df['trestbps']=='?'].shape[0])
print('Number of ? in chol', df[df['chol']=='?'].shape[0])
print('Number of ? in fbs', df[df['fbs']=='?'].shape[0])
print('Number of ? in restecg', df[df['restecg']=='?'].shape[0])
print('Number of ? in thalach', df[df['thalach']=='?'].shape[0])
print('Number of ? in exang', df[df['exang']=='?'].shape[0])
print('Number of ? in oldpeak', df[df['oldpeak']=='?'].shape[0])
print('Number of ? in slope', df[df['slope']=='?'].shape[0])
print('Number of ? in ca', df[df['ca']=='?'].shape[0])
print('Number of ? in thal', df[df['thal']=='?'].shape[0])
print('Number of ? in target', df[df['target']=='?'].shape[0])
# Out:
# Number of ? in age 0
# Number of ? in sex 0
# Number of ? in cp 0
# Number of ? in trestbps 59
# Number of ? in chol 30
# Number of ? in fbs 90
# Number of ? in restecg 2
# Number of ? in thalach 55
# Number of ? in exang 55
# Number of ? in oldpeak 62
# Number of ? in slope 309
# Number of ? in ca 611
# Number of ? in thal 486
# Number of ? in target 0

# %%
# Dropping the columns having '?' more than 30% :
df.drop(columns=['slope', 'ca', 'thal'], axis=1, inplace=True)

# %%
# Removing the rows containing '?' :
df = df[df['trestbps'] != '?']
df = df[df['chol'] != '?']
df = df[df['fbs'] != '?']
df = df[df['restecg'] != '?']
df = df[df['thalach'] != '?']
df = df[df['exang'] != '?']
df = df[df['oldpeak'] != '?']

# %%
# resetting index after dropping rows with '?':
df = df.reset_index()

# %%
# changing the format of datatypes:

df['age'] = df['age'].astype('int64')
df['sex'] = df['sex'].astype('int64')
df['cp'] = df['cp'].astype('int64')
df['trestbps'] = df['trestbps'].astype('int64')
df['chol'] = df['chol'].astype('int64')
df['fbs'] = df['fbs'].astype('int64')
df['restecg'] = df['restecg'].astype('int64')
df['thalach'] = df['thalach'].astype('int64')
df['exang'] = df['exang'].astype('int64')
df['oldpeak'] = df['oldpeak'].astype('float64')

# %%
df['target'].value_counts()
# Out:
# 0    357
# 1    204
# 2     79
# 3     78
# 4     22
# Name: target, dtype: int64

# %%
df['target'].replace(2,1,inplace=True)
df['target'].replace(3,1,inplace=True)
df['target'].replace(4,1,inplace=True)

# %%
df['target'].value_counts()
# Out:
# 1    383
# 0    357
# Name: target, dtype: int64

# %%
# Downloading the dataset:

df.to_csv('dataset-updated.csv', index=False)

# %%
import pandas as pd
import numpy as np

# %%
# loading the dataset into pandas dataframe:

df = pd.read_csv('dataset-updated.csv')

# %%
# Looking at first 5 rows 

df.head()
# Out:
#    index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      0   63    1   1       145   233    1        2      150      0      2.3
# 1      1   67    1   4       160   286    0        2      108      1      1.5
# 2      2   67    1   4       120   229    0        2      129      1      2.6
# 3      3   37    1   3       130   250    0        0      187      0      3.5
# 4      4   41    0   2       130   204    0        2      172      0      1.4
#
#    target
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0

# %%
# Looking at last 5 rows 

df.tail()
# Out:
#      index  age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 735    193   62    1   4       158   170    0        1      138      1
# 736    194   46    1   4       134   310    0        0      126      0
# 737    195   54    0   4       127   333    1        1      154      0
# 738    197   55    1   4       122   223    1        1      100      0
# 739    199   62    1   2       120   254    0        2       93      1
#
#      oldpeak  target
# 735      0.0       1
# 736      0.0       1
# 737      0.0       1
# 738      0.0       1
# 739      0.0       1

# %%
# describe() function to get various summary statistics

df.describe()
# Out:
#             index         age         sex          cp    trestbps        chol  \
# count  740.000000  740.000000  740.000000  740.000000  740.000000  740.000000
# mean   135.132432   53.097297    0.764865    3.227027  132.754054  220.136486
# std     84.905783    9.408127    0.424370    0.939193   18.581250   93.614555
# min      0.000000   28.000000    0.000000    1.000000    0.000000    0.000000
# 25%     61.000000   46.000000    1.000000    2.000000  120.000000  197.000000
# 50%    128.000000   54.000000    1.000000    4.000000  130.000000  231.000000
# 75%    202.250000   60.000000    1.000000    4.000000  140.000000  271.000000
# max    302.000000   77.000000    1.000000    4.000000  200.000000  603.000000
#
#               fbs     restecg     thalach       exang     oldpeak      target
# count  740.000000  740.000000  740.000000  740.000000  740.000000  740.000000
# mean     0.150000    0.635135  138.744595    0.400000    0.894324    0.517568
# ...

# %%
# identify the rows that contain missing values

df.isnull().sum()
# Out:
# index       0
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# target      0
# dtype: int64

# %%
df.shape
# Out:
# (740, 12)

# %%
df = df.drop('index', axis =1)

# %%
df.shape
# Out:
# (740, 11)

# %%
df['target'].value_counts()
# Out:
# 1    383
# 0    357
# Name: target, dtype: int64

# %%
# Downloading the dataset:

df.to_csv('dataset.csv', index=False)

# %% [markdown]
# I had solved three isssues to obtain the desired dataset:
#
# Removed the columns with more than 30% of '?'
# Removed the columns having '?'
# Changed the data types to their appopriate format based on their values
# This has resulted in a dataset with 720 rows and 11 columns.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.displot(df, x = 'target', bins = [0,0.25, 0.5, 0.75,1])
plt.grid()
plt.show()

# %%
ax = df['target'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Target', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Present || 0 - Absent)', fontsize=13)
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'target'],
#       dtype='object')

# %%
ax = df['age'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Target', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Present || 0 - Absent)', fontsize=13)
plt.show()

# %%
ax = df['sex'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Age', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Male || 0 - Female)', fontsize=13)
plt.show()

# %%
ax = df['cp'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
ax = df['trestbps'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
ax = df['chol'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
ax = df['fbs'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
ax = df['restecg'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
ax = df['thalach'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Chest pain type', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution', fontsize=13)
plt.show()

# %%
# calculate correlation matrix
import seaborn as sns
import matplotlib.pyplot as plt

corr = df.corr()

plt.subplots(figsize=(15,10))
sns.heatmap(corr, xticklabels=corr.columns, yticklabels=corr.columns, annot=True, cmap=sns.diverging_palette(220, 20, as_cmap=True))
plt.title("Correlation Heatmap", fontsize = 15)
plt.show()

# %%
ax = df['target'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Target', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Present || 0 - Absent)', fontsize=13)
plt.show()

# %%
ax = df['exang'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Target', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Present || 0 - Absent)', fontsize=13)
plt.show()

# %%
plt.hist(df['thalach'])
plt.show()

# %%
plt.hist(df['oldpeak'])
plt.show()

# %%
ax = df['oldpeak'].value_counts().sort_values().plot(kind="barh")
totals= []
for i in ax.patches:
    totals.append(i.get_width())
total = sum(totals)
for i in ax.patches:
     ax.text(i.get_width()+.3, i.get_y()+.20, 
     str(round((i.get_width()/total)*100, 2))+'%', 
     fontsize=10, color='black')
ax.grid(axis="x")
ax.set_ylabel('Target', fontsize = 12)
ax.set_xlabel('Count', fontsize = 12)
plt.suptitle('Class Distribution \n ( 1 - Present || 0 - Absent)', fontsize=13)
plt.show()

# %%
#subData = df[['age','trestbps','chol','thalach','oldpeak']]
sns.pairplot(df)
plt.show()

# %%
# features and traget
 
y = df['target'] # target class
df = df.drop(columns=['target'], axis = 1)
X = df # features

# %%
print(X)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 735   62    1   4       158   170    0        1      138      1      0.0
# 736   46    1   4       134   310    0        0      126      0      0.0
# 737   54    0   4       127   333    1        1      154      0      0.0
# 738   55    1   4       122   223    1        1      100      0      0.0
# 739   62    1   2       120   254    0        2       93      1      0.0
#
# [740 rows x 10 columns]

# %%
df.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# dtype: object

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  740.000000  740.000000  740.000000  740.000000  740.000000  740.000000
# mean    53.097297    0.764865    3.227027  132.754054  220.136486    0.150000
# std      9.408127    0.424370    0.939193   18.581250   93.614555    0.357313
# min     28.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%     46.000000    1.000000    2.000000  120.000000  197.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  231.000000    0.000000
# 75%     60.000000    1.000000    4.000000  140.000000  271.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#           restecg     thalach       exang     oldpeak
# count  740.000000  740.000000  740.000000  740.000000
# mean     0.635135  138.744595    0.400000    0.894324
# std      0.840039   25.846082    0.490229    1.087160
# ...

# %%
df.value_counts()
# Out:
# age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak
# 58   1    3   150       219   0    1        118      1      0.0        2
# 77   1    4   125       304   0    2        162      1      0.0        1
# 49   1    3   120       188   0    0        139      0      2.0        1
# 50   0    3   120       219   0    0        158      0      1.6        1
#           2   120       244   0    0        162      0      1.1        1
#                                                                       ..
# 58   0    3   120       340   0    0        172      0      0.0        1
#           2   180       393   0    0        110      1      1.0        1
#               136       319   1    2        152      0      0.0        1
#           1   150       283   1    2        162      0      1.0        1
# 28   1    2   130       132   0    2        185      0      0.0        1
# Length: 739, dtype: int64

# %%
# Scale features: center the data around mean 0 and std dev 1:

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)

# %%
print(rescaledX)
# Out:
# [[ 1.05328094  0.55445513 -2.37281763 ...  0.43577275 -0.81649658
#    1.29385439]
#  [ 1.47873284  0.55445513  0.82357505 ... -1.19033088  1.22474487
#    0.55749427]
#  [ 1.47873284  0.55445513  0.82357505 ... -0.37727906  1.22474487
#    1.56998944]
#  ...
#  [ 0.09601415 -1.80357244  0.82357505 ...  0.59063977 -0.81649658
#   -0.82318096]
#  [ 0.20237712  0.55445513  0.82357505 ... -1.50006491 -0.81649658
#   -0.82318096]
#  [ 0.94691796  0.55445513 -1.30735341 ... -1.77108218  1.22474487
#   -0.82318096]]

# %%
len(rescaledX)
# Out:
# 740

# %% [markdown]
# **Data Modelling and Training:**

# %%
# Dividing dataset into training and testing sets:

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(rescaledX, y, test_size=0.33, random_state=42)

# %%
print("Shape of training data:", X_train.shape)
# Out:
# Shape of training data: (495, 10)

# %%
print("Shape of test data:", X_test.shape)
# Out:
# Shape of test data: (245, 10)

# %%
# classification metrics

from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, confusion_matrix, roc_curve, auc

# %%
# Logistic regression

from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0).fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', confusion_matrix(y_test, y_pred))
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 96  25]
#  [ 18 106]]
# Accuracy score: 0.8244897959183674
# Recall score: 0.8548387096774194
# Precision score: 0.8091603053435115
# F1 score:  0.831372549019608

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8241135697147428

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Logistic Regression')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold

# %%
# solver, random_state, penalty, C, class_weight, multi_class and mix_iter
model = LogisticRegression()
penalty = ['l2', 'l1', 'elasticet']
solver = ['newton-cg', 'lbfgs', 'liblinear']
C = np.logspace(2^-5, 2^5)
max_iter = np.arange(10, 160,10)
multi_class = ['ovr']
# define grid search
grid = dict(penalty=penalty, solver = solver, C = C, max_iter = max_iter, multi_class = multi_class)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(X_train, y_train)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.796027 using {'C': 0.007196856730011514, 'max_iter': 10, 'multi_class': 'ovr', 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
clf = LogisticRegression(solver = 'newton-cg', C = 0.007196856730011514, penalty = 'l2', max_iter = 10, multi_class = 'ovr',
                         random_state=101).fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', confusion_matrix(y_test, y_pred))
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 96  25]
#  [ 18 106]]
# Accuracy score: 0.8244897959183674
# Recall score: 0.8548387096774194
# Precision score: 0.8091603053435115
# F1 score:  0.831372549019608

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Logistic Regression With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8241135697147428

# %%
# Naive Bayes classifier

from sklearn.naive_bayes import GaussianNB

clf = GaussianNB()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[102  19]
#  [ 25  99]]
# Accuracy score: 0.8204081632653061
# Recall score: 0.7983870967741935
# Precision score: 0.8389830508474576
# F1 score:  0.8181818181818181

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8206811516928818

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Naive Bayes classifier Without Optimization')
plt.show()

# %%
model = GaussianNB()
var_smoothing_values = np.logspace(0,-10,num=100)
# define grid search
grid = dict(var_smoothing = var_smoothing_values )
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(rescaledX, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.810360 using {'var_smoothing': 0.4977023564332111}

# %%
# Naive Bayes classifier

from sklearn.naive_bayes import GaussianNB

clf = GaussianNB(var_smoothing=0.4977023564332111)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[104  17]
#  [ 28  96]]
# Accuracy score: 0.8163265306122449
# Recall score: 0.7741935483870968
# Precision score: 0.8495575221238938
# F1 score:  0.810126582278481

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Naive Bayes classifier With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8168488403092509

# %%
# K-nearest neighbors classifer

from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier()
neigh.fit(X_train, y_train)
y_pred = neigh.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 91  30]
#  [ 21 103]]
# Accuracy score: 0.7918367346938775
# Recall score: 0.8306451612903226
# Precision score: 0.7744360902255639
# F1 score:  0.8015564202334631

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: KNN classifier Without Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7913556384964009

# %%
#List Hyperparameters that we want to tune.
model = KNeighborsClassifier()

leaf_size = list(range(1,40))
n_neighbors = list(range(1,20))
weights = ['uniform', 'distance']
algorithm = ['auto', 'ball_tree', 'kd_tree']
p=[1,2]
# define grid search
grid = dict(leaf_size = leaf_size, n_neighbors = n_neighbors, p = p, algorithm = algorithm, weights=weights )
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(rescaledX, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.806306 using {'algorithm': 'auto', 'leaf_size': 1, 'n_neighbors': 5, 'p': 1, 'weights': 'uniform'}

# %%
# K-nearest neighbors classifer
from sklearn.neighbors import KNeighborsClassifier

neigh = KNeighborsClassifier(n_neighbors=5, algorithm='auto', leaf_size=1, p=1, weights = 'uniform')
neigh.fit(X_train, y_train)
y_pred = neigh.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 95  26]
#  [ 22 102]]
# Accuracy score: 0.8040816326530612
# Recall score: 0.8225806451612904
# Precision score: 0.796875
# F1 score:  0.8095238095238094

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: KNN classifier With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8038523060517196

# %%
# Decision tree

from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state = 101)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[84 37]
#  [35 89]]
# Accuracy score: 0.7061224489795919
# Recall score: 0.717741935483871
# Precision score: 0.7063492063492064
# F1 score:  0.712

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Decision Tree classifier Without Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7059784057584644

# %%
model = DecisionTreeClassifier(random_state=0)

criterion = ["gini", "entropy"]
splitter = ['best', 'random']
max_depth = np.arange(1,20,1)
max_features = np.linspace(0,1,10)
min_samples_leaf = np.arange(1,20)
min_samples_split = np.arange(1,20)


# define grid search
grid = dict(max_depth = max_depth, min_samples_leaf = min_samples_leaf, criterion = criterion,
            min_samples_split=min_samples_split, splitter = splitter, max_features= max_features)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(rescaledX, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.807658 using {'criterion': 'gini', 'max_depth': 4, 'max_features': 0.5555555555555556, 'min_samples_leaf': 1, 'min_samples_split': 19, 'splitter': 'best'}

# %%
# Decision tree

from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(max_depth=4, criterion = 'gini', min_samples_leaf=1, max_features = 0.5555555555555556,
                             splitter = 'best', min_samples_split =19, random_state=10)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 86  35]
#  [ 21 103]]
# Accuracy score: 0.7714285714285715
# Recall score: 0.8306451612903226
# Precision score: 0.7463768115942029
# F1 score:  0.7862595419847328

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Decision Tree classifier With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7706944814716077

# %%
# Random forest classifier

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(random_state=1)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 90  31]
#  [ 18 106]]
# Accuracy score: 0.8
# Recall score: 0.8548387096774194
# Precision score: 0.7737226277372263
# F1 score:  0.8122605363984675

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Random Forest classifier Without Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7993201812849907

# %%
model = RandomForestClassifier(random_state=0)

bootstrap = [True, False]
criterion = ["gini", "entropy"]
max_features = ['auto', 'sqrt', 'log']
min_samples_leaf = np.arange(1,20,1)
min_samples_split = np.arange(2,20,1)
max_depth = np.arange(1,10,1)

# define grid search
grid = dict(max_depth = max_depth, max_features=max_features, min_samples_leaf=min_samples_leaf, min_samples_split=min_samples_split, 
            bootstrap = bootstrap, criterion = criterion)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(rescaledX, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.799550 using {'bootstrap': True, 'criterion': 'entropy', 'max_depth': 9, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 17}

# %%
# Random forest classifier

from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(max_depth=9, random_state=10, criterion='entropy', max_features='auto', min_samples_leaf=1, 
                            min_samples_split = 17, bootstrap = True)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 87  34]
#  [ 17 107]]
# Accuracy score: 0.7918367346938775
# Recall score: 0.8629032258064516
# Precision score: 0.7588652482269503
# F1 score:  0.8075471698113207

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: Random Forest classifier With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7909557451346307

# %%
# Support vector machine classifier

from sklearn.svm import SVC

clf = SVC(random_state = 101)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 89  32]
#  [ 18 106]]
# Accuracy score: 0.7959183673469388
# Recall score: 0.8548387096774194
# Precision score: 0.7681159420289855
# F1 score:  0.8091603053435115

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: SVM classifier Without Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.7951879498800319

# %%
model = SVC()
gamma = np.logspace(2^-10,2^10,100)
C = np.logspace(2^-10, 2^10,100)
tol = np.logspace(10^-5,10^-5,100)
shrinking = [True, False]
kernel = ['linear', 'poly', 'sigmoid', 'rbf']

# define grid search
grid = dict(gamma=gamma, C=C, tol = tol, shrinking = shrinking)
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
grid_search = GridSearchCV(estimator=model, param_grid=grid, n_jobs=-1, cv=cv, scoring='accuracy',error_score=0)
grid_result = grid_search.fit(rescaledX, y)
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# Best: 0.802252 using {'C': 10000000.0, 'gamma': 1e-07, 'tol': 1e-10}

# %%
# Support vector machine classifier

from sklearn.svm import SVC

clf = SVC(gamma=1e-07, C = 10000000.0, tol = 1e-10, kernel = 'rbf', shrinking = True)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

cf_matrix = confusion_matrix(y_test, y_pred)
print('Confusion matrix:', cf_matrix)
print('Accuracy score:', accuracy_score(y_test, y_pred))
print('Recall score:', recall_score(y_test, y_pred))
print('Precision score:', precision_score(y_test, y_pred))
print('F1 score: ', f1_score(y_test, y_pred))
# Out:
# Confusion matrix: [[ 97  24]
#  [ 16 108]]
# Accuracy score: 0.8367346938775511
# Recall score: 0.8709677419354839
# Precision score: 0.8181818181818182
# F1 score:  0.84375

# %%
group_names = ['True Neg','False Pos','False Neg','True Pos']
group_counts = ["{0:0.0f}".format(value) for value in
                cf_matrix.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in
                     cf_matrix.flatten()/np.sum(cf_matrix)]
labels = [f"{v1}\n{v2}\n{v3}" for v1, v2, v3 in
          zip(group_names,group_counts,group_percentages)]
labels = np.asarray(labels).reshape(2,2)
sns.heatmap(cf_matrix, annot=labels, fmt='', cmap='Blues')
plt.title('Confusion Matrix: SVM classifier With Optimization')
plt.show()

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc(fpr, tpr)
# Out:
# 0.8363103172487337
